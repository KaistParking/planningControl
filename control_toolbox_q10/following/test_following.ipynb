# %% [markdown]
# # Custom Follower

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import mpc.model_predictive_speed_and_steer_control as mpc
import mpc.cubic_spline_planner as sample_planner

import math
import numpy as np
import matplotlib.pyplot as plt
import os
import sys

# %% [markdown]
# ### get sample course

# %%
def get_switch_back_course(dl):
    ax = [0.0, 30.0, 6.0, 20.0, 35.0]
    ay = [0.0, 0.0, 20.0, 35.0, 20.0]
    cx, cy, cyaw, ck, s = sample_planner.calc_spline_course(
        ax, ay, ds=dl)
    ax = [35.0, 10.0, 0.0, 0.0]
    ay = [20.0, 30.0, 5.0, 0.0]
    cx2, cy2, cyaw2, ck2, s2 = sample_planner.calc_spline_course(
        ax, ay, ds=dl)
    cyaw2 = [i - math.pi for i in cyaw2]
    cx.extend(cx2)
    cy.extend(cy2)
    cyaw.extend(cyaw2)
    ck.extend(ck2)

    return cx, cy, cyaw, ck

# %%
dl = 1.0  # course tick
cx, cy, cyaw, ck = get_switch_back_course(dl)

# %% [markdown]
# ### Following Properties

# %%
NX = 4  # x = x, y, v, yaw
NU = 2  # a = [accel, steer]
T = 5  # horizon length

# mpc parameters
R = np.diag([0.01, 0.01])  # input cost matrix
Rd = np.diag([0.01, 1.0])  # input difference cost matrix
Q = np.diag([1.0, 1.0, 0.5, 0.5])  # state cost matrix
Qf = Q  # state final matrix
GOAL_DIS = 1.5  # goal distance
STOP_SPEED = 0.5 / 3.6  # stop speed
MAX_TIME = 500.0  # max simulation time

# iterative paramter
MAX_ITER = 3  # Max iteration
DU_TH = 0.1  # iteration finish param

TARGET_SPEED = 10.0 / 3.6  # [m/s] target speed
N_IND_SEARCH = 10  # Search index number

DT = 0.2  # [s] time tick

# Vehicle parameters
LENGTH = 4.5  # [m]
WIDTH = 2.0  # [m]
BACKTOWHEEL = 1.0  # [m]
WHEEL_LEN = 0.3  # [m]
WHEEL_WIDTH = 0.2  # [m]
TREAD = 0.7  # [m]
WB = 2.5  # [m]

MAX_STEER = np.deg2rad(45.0)  # maximum steering angle [rad]
MAX_DSTEER = np.deg2rad(30.0)  # maximum steering speed [rad/s]
MAX_SPEED = 55.0 / 3.6  # maximum speed [m/s]
MIN_SPEED = -20.0 / 3.6  # minimum speed [m/s]
MAX_ACCEL = 1.0  # maximum accel [m/ss]

# %%
sp = mpc.calc_speed_profile(cx, cy, cyaw, TARGET_SPEED)

initial_state = mpc.State(x=cx[0], y=cy[0], yaw=cyaw[0], v=0.0)

# t, x, y, yaw, v, d, a = do_simulation(
#     cx, cy, cyaw, ck, sp, dl, initial_state)

# %%
def do_simulation(cx, cy, cyaw, ck, sp, dl, initial_state):
    goal = [cx[-1], cy[-1]]

    state = initial_state

    # initial yaw compensation
    if state.yaw - cyaw[0] >= math.pi:
        state.yaw -= math.pi * 2.0
    elif state.yaw - cyaw[0] <= -math.pi:
        state.yaw += math.pi * 2.0

    time = 0.0
    x = [state.x]
    y = [state.y]
    yaw = [state.yaw]
    v = [state.v]
    t = [0.0]
    d = [0.0]
    a = [0.0]
    target_ind, _ = calc_nearest_index(state, cx, cy, cyaw, 0)

    odelta, oa = None, None

    cyaw = smooth_yaw(cyaw)

    while MAX_TIME >= time:
        xref, target_ind, dref = calc_ref_trajectory(
            state, cx, cy, cyaw, ck, sp, dl, target_ind)

        x0 = [state.x, state.y, state.v, state.yaw]  # current state

        oa, odelta, ox, oy, oyaw, ov = iterative_linear_mpc_control(
            xref, x0, dref, oa, odelta)

        if odelta is not None:
            di, ai = odelta[0], oa[0]

        state = update_state(state, ai, di)
        time = time + DT

        x.append(state.x)
        y.append(state.y)
        yaw.append(state.yaw)
        v.append(state.v)
        t.append(time)
        d.append(di)
        a.append(ai)

        if check_goal(state, goal, target_ind, len(cx)):
            print("Goal")
            break


    return t, x, y, yaw, v, d, a

# %%
from mpc.model_predictive_speed_and_steer_control import *
import mpc.cubic_spline_planner as cubic_spline_planner

# %%
print("start!!")

dl = 1.0  # course tick
# cx, cy, cyaw, ck = get_straight_course(dl)
# cx, cy, cyaw, ck = get_straight_course2(dl)
# cx, cy, cyaw, ck = get_straight_course3(dl)
# cx, cy, cyaw, ck = get_forward_course(dl)
cx, cy, cyaw, ck = get_switch_back_course(dl)

sp = calc_speed_profile(cx, cy, cyaw, TARGET_SPEED)

initial_state = State(x=cx[0], y=cy[0], yaw=cyaw[0], v=0.0)

t, x, y, yaw, v, d, a = do_simulation(
    cx, cy, cyaw, ck, sp, dl, initial_state)
# Out:
# start!!
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
# ...
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /home/q10/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f31e3119ff8a> in <module>
#      13
#      14 t, x, y, yaw, v, d, a = do_simulation(
# ---> 15     cx, cy, cyaw, ck, sp, dl, initial_state)
#      16
#      17 if show_animation:  # pragma: no cover
#
# ~/ws/repos/kaist_parking/control/control_toolbox_q10/following/mpc/model_predictive_speed_and_steer_control.py in do_simulation(cx, cy, cyaw, ck, sp, dl, initial_state)
#     403
#     404         oa, odelta, ox, oy, oyaw, ov = iterative_linear_mpc_control(
# --> 405             xref, x0, dref, oa, odelta)
#     406
#     407         if odelta is not None:
#
# ~/ws/repos/kaist_parking/control/control_toolbox_q10/following/mpc/model_predictive_speed_and_steer_control.py in iterative_linear_mpc_control(xref, x0, dref, oa, od)
#     235         xbar = predict_motion(x0, oa, od, xref)
#     236         poa, pod = oa[:], od[:]
# --> 237         oa, od, ox, oy, oyaw, ov = linear_mpc_control(xref, xbar, x0, dref)
#     238         du = sum(abs(oa - poa)) + sum(abs(od - pod))  # calc u change value
#     239         if du <= DU_TH:
#
# ~/ws/repos/kaist_parking/control/control_toolbox_q10/following/mpc/model_predictive_speed_and_steer_control.py in linear_mpc_control(xref, xbar, x0, dref)
#     285
#     286     prob = cvxpy.Problem(cvxpy.Minimize(cost), constraints)
# --> 287     prob.solve(solver=cvxpy.ECOS, verbose=False)
#     288
#     289     if prob.status == cvxpy.OPTIMAL or prob.status == cvxpy.OPTIMAL_INACCURATE:
#
# ~/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/problems/problem.py in solve(self, *args, **kwargs)
#     394         else:
#     395             solve_func = Problem._solve
# --> 396         return solve_func(self, *args, **kwargs)
#     397
#     398     @classmethod
#
# ~/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/problems/problem.py in _solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, **kwargs)
#     749
#     750         data, solving_chain, inverse_data = self.get_problem_data(
# --> 751             solver, gp, enforce_dpp)
#     752         solution = solving_chain.solve_via_data(
#     753             self, data, warm_start, verbose, kwargs)
#
# ~/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/problems/problem.py in get_problem_data(self, solver, gp, enforce_dpp)
#     523             inverse_data = self._cache.inverse_data + [solver_inverse_data]
#     524         else:
# --> 525             data, inverse_data = solving_chain.apply(self)
#     526             safe_to_cache = (
#     527                 isinstance(data, dict)
#
# ~/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/reductions/chain.py in apply(self, problem)
#      69         inverse_data = []
#      70         for r in self.reductions:
# ---> 71             problem, inv = r.apply(problem)
#      72             inverse_data.append(inv)
#      73         return problem, inverse_data
#
# ~/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/reductions/solvers/conic_solvers/ecos_conif.py in apply(self, problem)
#     110         len_eq = problem.cone_dims.zero
#     111
# --> 112         c, d, A, b = problem.apply_parameters()
#     113         data[s.C] = c
#     114         inv_data[s.OFFSET] = d
#
# ~/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/reductions/dcp2cone/cone_matrix_stuffing.py in apply_parameters(self, id_to_param_value, zero_offset, keep_zeros)
#     174             zero_offset=zero_offset)
#     175         c, d = canonInterface.get_matrix_from_tensor(
# --> 176             self.c, param_vec, self.x.size, with_offset=True)
#     177         c = c.toarray().flatten()
#     178         if keep_zeros and self._A_mapping_nonzero is None:
#
# ~/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/cvxpy/cvxcore/python/canonInterface.py in get_matrix_from_tensor(problem_data_tensor, param_vec, var_length, nonzero_rows, with_offset, problem_data_index)
#     243         if with_offset:
#     244             n_cols += 1
# --> 245         M = flat_problem_data.reshape((-1, n_cols), order='F').tocsc()
#     246
#     247     if with_offset:
#
# ~/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/scipy/sparse/base.py in reshape(self, *args, **kwargs)
#     125                 return self
#     126
# --> 127         return self.tocoo(copy=copy).reshape(shape, order=order, copy=False)
#     128
#     129     def resize(self, shape):
#
# ~/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/scipy/sparse/compressed.py in tocoo(self, copy)
#    1016         from .coo import coo_matrix
#    1017         return coo_matrix((self.data, (row, col)), self.shape, copy=copy,
# -> 1018                           dtype=self.dtype)
#    1019
#    1020     tocoo.__doc__ = spmatrix.tocoo.__doc__
#
# ~/.pyenv/versions/miniconda3-4.7.12/lib/python3.7/site-packages/scipy/sparse/coo.py in __init__(self, arg1, shape, dtype, copy)
#     155
#     156                 idx_dtype = get_index_dtype(maxval=max(self.shape))
# --> 157                 self.row = np.array(row, copy=copy, dtype=idx_dtype)
#     158                 self.col = np.array(col, copy=copy, dtype=idx_dtype)
#     159                 self.data = np.array(obj, copy=copy)
#
# KeyboardInterrupt:

# %%
def get_switch_back_course(dl):
    ax = [0.0, 30.0, 6.0, 20.0, 35.0]
    ay = [0.0, 0.0, 20.0, 35.0, 20.0]
    cx, cy, cyaw, ck, s = cubic_spline_planner.calc_spline_course(
        ax, ay, ds=dl)
    ax = [35.0, 10.0, 0.0, 0.0]
    ay = [20.0, 30.0, 5.0, 0.0]
    cx2, cy2, cyaw2, ck2, s2 = cubic_spline_planner.calc_spline_course(
        ax, ay, ds=dl)
    cyaw2 = [i - math.pi for i in cyaw2]
    cx.extend(cx2)
    cy.extend(cy2)
    cyaw.extend(cyaw2)
    ck.extend(ck2)

    return cx, cy, cyaw, ck

# %%
cx2
# Out:
# [35.0,
#  33.95976077352365,
#  32.9204477559058,
#  31.88298715600492,
#  30.84830518267951,
#  29.817328044788063,
#  28.790981951189057,
#  27.770193110740994,
#  26.75588773230236,
#  25.74899202473164,
#  24.750432196887328,
#  23.761134457627914,
#  22.782025015811886,
#  21.814030080297734,
#  20.85807585994395,
#  19.91508856360901,
#  18.985994400151426,
#  18.07171957842968,
#  17.17319030730225,
#  16.29133279562764,
#  15.42707325226433,
#  14.581337886070813,
#  13.755052905905583,
#  12.949144520627126,
#  12.164538939093926,
#  11.402162370164483,
#  10.662941022697282,
#  9.947801041143363,
#  9.257473225805729,
#  8.592062136179576,
#  7.951547094989254,
#  7.3359074249591325,
#  6.74512244881357,
#  6.179171489276925,
#  5.6380338690735625,
#  5.121688910927843,
#  4.630115937564126,
#  4.163294271706772,
#  3.7212032360801466,
#  3.303822153408606,
#  2.911130346416516,
#  2.5431071378282333,
#  2.199731850368123,
#  1.880983806760542,
#  1.5868423297298542,
#  1.3172867420004226,
#  1.0722963662966043,
#  0.8518505253427621,
#  0.6559285418632596,
#  0.4845097385824543,
#  0.33757343822471125,
#  0.21509896351438434,
#  0.11706563717584462,
#  0.04345278193344788,
#  -0.005762921809052823,
#  -0.03181977408174195,
#  -0.03909430791354439,
#  -0.032462960116177414,
#  -0.01680216750135826]

# %%
def do_simulation(cx, cy, cyaw, ck, sp, dl, initial_state):
    """
    Simulation

    cx: course x position list
    cy: course y position list
    cy: course yaw position list
    ck: course curvature list
    sp: speed profile
    dl: course tick [m]

    """

    goal = [cx[-1], cy[-1]]

    state = initial_state

    # initial yaw compensation
    if state.yaw - cyaw[0] >= math.pi:
        state.yaw -= math.pi * 2.0
    elif state.yaw - cyaw[0] <= -math.pi:
        state.yaw += math.pi * 2.0

    time = 0.0
    x = [state.x]
    y = [state.y]
    yaw = [state.yaw]
    v = [state.v]
    t = [0.0]
    d = [0.0]
    a = [0.0]
    target_ind, _ = calc_nearest_index(state, cx, cy, cyaw, 0)

    odelta, oa = None, None

    cyaw = smooth_yaw(cyaw)

    while MAX_TIME >= time:
        xref, target_ind, dref = calc_ref_trajectory(
            state, cx, cy, cyaw, ck, sp, dl, target_ind)

        x0 = [state.x, state.y, state.v, state.yaw]  # current state

        oa, odelta, ox, oy, oyaw, ov = iterative_linear_mpc_control(
            xref, x0, dref, oa, odelta)

        if odelta is not None:
            di, ai = odelta[0], oa[0]

        state = update_state(state, ai, di)
        time = time + DT

        x.append(state.x)
        y.append(state.y)
        yaw.append(state.yaw)
        v.append(state.v)
        t.append(time)
        d.append(di)
        a.append(ai)

        if check_goal(state, goal, target_ind, len(cx)):
            print("Goal")
            break

        if show_animation:  # pragma: no cover
            plt.cla()
            # for stopping simulation with the esc key.
            plt.gcf().canvas.mpl_connect('key_release_event',
                                         lambda event: [exit(0) if event.key == 'escape' else None])
            if ox is not None:
                plt.plot(ox, oy, "xr", label="MPC")
            plt.plot(cx, cy, "-r", label="course")
            plt.plot(x, y, "ob", label="trajectory")
            plt.plot(xref[0, :], xref[1, :], "xk", label="xref")
            plt.plot(cx[target_ind], cy[target_ind], "xg", label="target")
            plot_car(state.x, state.y, state.yaw, steer=di)
            plt.axis("equal")
            plt.grid(True)
            plt.title("Time[s]:" + str(round(time, 2))
                      + ", speed[km/h]:" + str(round(state.v * 3.6, 2)))
            plt.pause(0.0001)

    return t, x, y, yaw, v, d, a

# %%
def update_state(state, a, delta, dt):
    if delta >= MAX_STEER:
        delta = MAX_STEER
    elif delta <= -MAX_STEER:
        delta = -MAX_STEER
    state.x = state.x + state.v * math.cos(state.yaw) * dt
    state.y = state.y + state.v * math.sin(state.yaw) * dt
    state.yaw = state.yaw + state.v / WB * math.tan(delta) * dt
    state.v = state.v + a * dt
    if state.v > MAX_SPEED:
        state.v = MAX_SPEED
    elif state.v < MIN_SPEED:
        state.v = MIN_SPEED
    return state
